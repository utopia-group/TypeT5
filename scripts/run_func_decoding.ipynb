# %%
# %load_ext autoreload
# %autoreload 2

# first, load the trained model
import os
import torch
from typing import *

from spot.model import ModelWrapper
from spot.utils import get_model_dir, proj_root, get_gpu_id

os.chdir(proj_root())

gpu_id = get_gpu_id(1)
modeldir = get_model_dir()

# model_name="model-v4--TrainingConfig(func_only=True, drop_env_types=False, left_margin=1536, preamble_size=768, right_margin=2048)"
model_name="model-v6--TrainingConfig(drop_env_types=False)"
wrapper = ModelWrapper.from_pretrained(
    modeldir / model_name
)
device = torch.device(f"cuda:{gpu_id}" if torch.cuda.is_available() else "cpu")
wrapper.to(device)
print(f"Model loaded to {device}")
# Out:
# GPU_ID not set, using: 1
# Model loaded to cuda:1

# %%
from spot.static_analysis import (
    PythonProject,
    PythonModule,
    UsageAnalysis,
    mask_types,
    remove_comments,
)
from spot.utils import *
from spot.function_dataset import data_project_from_dir
from spot.visualization import show_code_range


ex_project = data_project_from_dir(Path("/mnt/data0/jiayi/SPOT/datasets/ManyTypes4Py/repos/test/nabla-c0d3__sslyze"))

# %%
from spot.function_decoding import (
    RolloutCtx,
    PreprocessArgs,
    DecodingOrders,
    ProcessPoolExecutor,
    ThreadPoolExecutor,
    AccuracyMetric,
)
from spot.model import DecodingArgs
from spot.visualization import pretty_print_dict

ctx_args = wrapper.args.ctx_args
wrapper.args = DecodingArgs(
    sampling_max_tokens=ctx_args.ctx_size,
    ctx_args=ctx_args,
    do_sample=False,
    num_beams=10,
    tokens_per_type=16,
    # length_penalty=0.2,
)


rctx = RolloutCtx(
    model=wrapper,
)

pre_args = PreprocessArgs()

evalr = await rctx.evaluate_on_projects(
    [ex_project], pre_args, DecodingOrders.DoubleTraversal(),
)

metric = AccuracyMetric(wrapper.common_type_names)
pretty_print_dict(evalr.error_analysis(None, metric).accuracies)
# Out:
# evaluate_on_projects: 100%|██████████| 2359/2359 [24:52<00:00,  1.58it/s]
# acc: 75.82% (count=947)
# acc_by_common:
#    rare: 67.86% (count=560)
#    common: 87.34% (count=387)
# acc_by_cat:
#    FuncArg: 80.17% (count=343)
#    FuncReturn: 73.60% (count=250)
#    ClassAtribute: 73.35% (count=349)
#    GlobalVar: 60.00% (count=5)
# acc_label_size: 1.2693
# acc_pred_size: 1.2555
# acc_ignored_labels: 62
# n_skipped_types: 0
# n_missing_types: 0

# %%
metric = AccuracyMetric(wrapper.common_type_names)
pretty_print_dict(evalr.error_analysis(None, metric).accuracies)
# Out:
# acc: 76.98% (count=947)
# acc_by_common:
#    rare: 70.36% (count=560)
#    common: 86.56% (count=387)
# acc_by_cat:
#    FuncArg: 81.34% (count=343)
#    FuncReturn: 75.60% (count=250)
#    ClassAtribute: 73.93% (count=349)
#    GlobalVar: 60.00% (count=5)
# acc_label_size: 1.2693
# acc_pred_size: 1.2777
# acc_ignored_labels: 62
# n_skipped_types: 0
# n_missing_types: 0

# %%
pid = evalr.project_roots.index(ex_project.root_dir)
ex_analysis = evalr.error_analysis(pid, metric)
ex_errors = ex_analysis.errors[ex_project.root_dir.name]
ex_rollout = evalr.predictions[pid]

print("Number of errors:", len(ex_errors))
# Out:
# Number of errors: 229

# %%
from spot.static_analysis import ProjectPath

error_id = 3
pred = ex_errors[error_id]
print("----------------------")
print("Elem Path:", pred.path)
print("Type Index:", pred.index)
evalr.inspect_elem(pid, pred.path)
# Out:
# ----------------------
# Elem Path: tests.scanner_tests.test_mass_scanner/TestMassScannerProducerThread.PluginImplThatTriggersConnectivityError._scan_job_work_function
# Type Index: 1
# Expected:  MethodSig((arg1: str) -> str)
# Predicted: MethodSig((arg1: str) -> None)
# Code:
# import threading
# from unittest import mock
# from sslyze.plugins.scan_commands import ScanCommandsRepository
# from sslyze.scanner._mass_scanner import MassScannerProducerThread, NoMoreServerScanRequestsSentinel
# from sslyze.server_connectivity import ServerConnectivityInfo
# from tests.factories import ServerScanRequestFactory, ServerTlsProbingResultFactory
# from typing import Optional, List
# from queue import Queue
# from pathlib import Path
# from sslyze import (
#     ScanCommand,
#     ServerConnectivityStatusEnum,
#     ServerScanStatusEnum,
#     ScanCommandAttemptStatusEnum,
#     ScanCommandsExtraArguments,
#     CertificateInfoExtraArgument,
#     ScanCommandErrorReasonEnum,
# )
# from sslyze.errors import TlsHandshakeTimedOut
# from sslyze.plugins.plugin_base import (
#     ScanCommandImplementation,
#     ScanCommandExtraArgument,
#     ScanJob,
#     ScanCommandResult,
#     ScanJobResult,
# )
# from tests.scanner_tests.conftest import MockPluginScanResult
# class TestMassScannerProducerThread:
#    ...
# # tests.scanner_tests.conftest
# @dataclass(frozen=True)
# class MockPluginScanResult(ScanCommandResult):
#     results_field: List[str]
#     did_receive_extra_arguments: bool = False
#
# # tests.factories
# class ServerTlsProbingResultFactory:
#     @staticmethod
#     def create(
#         client_auth_requirement: ClientAuthRequirementEnum = ClientAuthRequirementEnum.DISABLED,
#     ) -> ServerTlsProbingResult:...
#
#
# # tests.factories
# class ServerScanRequestFactory:
#     @staticmethod
#     def create(
#         server_location: Optional[ServerNetworkLocation] = None,
#         scan_commands: Optional[Set[ScanCommand]] = None,
#         scan_commands_extra_arguments: Optional[ScanCommandsExtraArguments] = None,
#     ) -> ServerScanRequest:...
#
#
# # sslyze.scanner._mass_scanner
# class MassScannerProducerThread(threading.Thread):
#     def __init__(
#         self,
#         concurrent_server_scans_count: int,
#         per_server_concurrent_connections_count: int,
#         server_scan_requests_queue_in: queue.Queue[ServerScanRequest],
#         server_scan_results_queue_out: queue.Queue[ServerScanResult],
#     ) -> None:...
#
#
# # sslyze.plugins.plugin_base
# @dataclass(frozen=True)
# class ScanJob:
#     function_to_call: Callable[..., ScanJob]
#     function_arguments: List[Tuple[ServerInfo, ServerConnectivityInfo, ServerConnectivityInfo]]
#
# # sslyze.plugins.plugin_base
# class ScanCommandImplementation(Generic[_ScanCommandResultTypeVar, _ScanCommandExtraArgumentTypeVar]):
#     @classmethod
#     @abstractmethod
#     def scan_jobs_for_scan_command(
#         cls: Type[ScanJob], server_info: ServerConnectivityInfo, extra_arguments: Optional[ScanCommandExtraArgumentTypeVar] = None
#     ) -> List[ScanJob]:...
#
#
# # sslyze.scanner.models
# @dataclass(frozen=True)
# class ServerScanResult:
#     server_location: ServerNetworkLocation
#     network_configuration: ServerNetworkConfiguration
#
# # sslyze.server_connectivity
# @dataclass(frozen=True)
# class ServerConnectivityInfo:
#     server_location: ServerNetworkLocation
#     network_configuration: ServerNetworkConfiguration
#
# # sslyze.scanner.models
# @dataclass(frozen=True)
# class ServerScanRequest:
#     server_location: ServerNetworkLocation
#     network_configuration: Optional[ServerNetworkConfiguration] = field(default=None)
#
# # sslyze.json.json_output
# class ServerScanResultAsJson(_BaseModelWithOrmModeAndForbid):
#     server_location: ServerNetworkLocation
#     network_configuration: ServerNetworkConfiguration
#
# # sslyze.errors
# @dataclass(frozen=True)
# class ConnectionToServerFailed(Exception):
#     server_location: ServerNetworkLocation
#     network_configuration: ServerNetworkConfiguration
#     error_message: str
#
# # Used above
# # tests.scanner_tests.test_mass_scanner
# class PluginImplThatTriggersConnectivityError(ScanCommandImplementation):
#     @staticmethod
#     def _scan_job_work_function(arg1: <extra_id_0>) -> <extra_id_1>:
#         raise TlsHandshakeTimedOut(
#             server_location=server_scan_request.server_location,
#             network_configuration=server_scan_request.network_configuration,
#             error_message="error",
#         )
#
#
# # Users below
# # tests.scanner_tests.conftest
# class _MockPluginImplementation(ScanCommandImplementation):
#     @classmethod
#     def scan_jobs_for_scan_command(
#         cls: Type[ScanJob], server_info: ServerConnectivityInfo, extra_arguments: Optional[ScanCommandExtraArgumentTypeVar] = None
#     ) -> List[ScanJob]:
#         did_receive_extra_arguments = extra_arguments is not None
#         scan_jobs = [
#             ScanJob(
#                 function_to_call=cls._scan_job_work_function,
#                 function_arguments=["test", 12, did_receive_extra_arguments],
#             )
#             for _ in range(cls._scan_jobs_count)
#         ]
#         return scan_jobs
#
#
# # tests.scanner_tests.test_mass_scanner
# class TestMassScannerProducerThread:
#     def test_error_bug_in_sslyze_when_processing_job_results(self) -> None:
#         server_scan_requests_queue_in = Queue()
#         server_scan_results_queue_out = Queue()
#         mass_scanner_thread = MassScannerProducerThread(
#             concurrent_server_scans_count=5,
#             per_server_concurrent_connections_count=5,
#             server_scan_requests_queue_in=server_scan_requests_queue_in,
#             server_scan_results_queue_out=server_scan_results_queue_out,
#         )
#         mass_scanner_thread.start()
#
#         server_scan_request = ServerScanRequestFactory.create(scan_commands={ScanCommand.CERTIFICATE_INFO})
#         server_connectivity_result = ServerTlsProbingResultFactory.create()
#
#         class PluginImplThatCrashesWhenProcessingJobs(ScanCommandImplementation):
#             @staticmethod
#             def _scan_job_work_function(arg1):
#                 return f"{arg1}-do nothing"
#
#             @classmethod
#             def scan_jobs_for_scan_command(
#                 cls, server_info, extra_arguments = None
#             ):
#                 scan_jobs = [
#                     ScanJob(function_to_call=cls._scan_job_work_function, function_arguments=["test"]) for _ in range(5)
#                 ]
#                 return scan_jobs
#
#             @classmethod
#             def result_for_completed_scan_jobs(
#                 cls, server_info, scan_job_results
#             ):
#                 raise KeyError("Some unexpected error when processing scan jobs")
#
#         with mock.patch.object(
#             ScanCommandsRepository, "get_implementation_cls", return_value=PluginImplThatCrashesWhenProcessingJobs
#         ):
#             server_scan_requests_queue_in.put((server_scan_request, server_connectivity_result))
#             server_scan_requests_queue_in.put(NoMoreServerScanRequestsSentinel())
#
#             all_server_scan_results = []
#             while True:
#                 result = server_scan_results_queue_out.get(block=True)
#                 server_scan_results_queue_out.task_done()
#                 if isinstance(result, NoMoreServerScanRequestsSentinel):
#                     break
#                 all_server_scan_results.append(result)
#
#             assert len(all_server_scan_results) == 1
#             scan_command_result = all_server_scan_results[0].scan_result.certificate_info
#
#             assert scan_command_result.status == ScanCommandAttemptStatusEnum.ERROR
#             assert scan_command_result.error_reason == ScanCommandErrorReasonEnum.BUG_IN_SSLYZE
#             assert scan_command_result.error_trace
#             assert scan_command_result.result is None
#
#     def test_error_server_connectivity_issue_handshake_timeout(self) -> None:
#         server_scan_requests_queue_in = Queue()
#         server_scan_results_queue_out = Queue()
#         mass_scanner_thread = MassScannerProducerThread(
#             concurrent_server_scans_count=5,
#             per_server_concurrent_connections_count=5,
#             server_scan_requests_queue_in=server_scan_requests_queue_in,
#             server_scan_results_queue_out=server_scan_results_queue_out,
#         )
#         mass_scanner_thread.start()
#
#         server_scan_request = ServerScanRequestFactory.create(scan_commands={ScanCommand.CERTIFICATE_INFO})
#         server_connectivity_result = ServerTlsProbingResultFactory.create()
#
#         class PluginImplThatTriggersConnectivityError(ScanCommandImplementation):
#             @staticmethod
#             def _scan_job_work_function(arg1):
#                 raise TlsHandshakeTimedOut(
#                     server_location=server_scan_request.server_location,
#                     network_configuration=server_scan_request.network_configuration,
#                     error_message="error",
#                 )
#
#             @classmethod
#             def scan_jobs_for_scan_command(
#                 cls, server_info, extra_arguments = None
#             ):
#                 return [ScanJob(function_to_call=cls._scan_job_work_function, function_arguments=["test"])]
#
#             @classmethod
#             def result_for_completed_scan_jobs(
#                 cls, server_info, scan_job_results
#             ):
#                 for completed_job in scan_job_results:
#                     completed_job.get_result()
#                 return MockPluginScanResult(results_field=["ok"])
#
#         with mock.patch.object(
#             ScanCommandsRepository, "get_implementation_cls", return_value=PluginImplThatTriggersConnectivityError
#         ):
#             server_scan_requests_queue_in.put((server_scan_request, server_connectivity_result))
#             server_scan_requests_queue_in.put(NoMoreServerScanRequestsSentinel())
#
#             all_server_scan_results = []
#             while True:
#                 result = server_scan_results_queue_out.get(block=True)
#                 server_scan_results_queue_out.task_done()
#                 if isinstance(result, NoMoreServerScanRequestsSentinel):
#                     break
#                 all_server_scan_results.append(result)
#
#             assert len(all_server_scan_results) == 1
#             scan_command_result = all_server_scan_results[0].scan_result.certificate_info
#
#             assert scan_command_result.status == ScanCommandAttemptStatusEnum.ERROR
#             assert scan_command_result.error_reason == ScanCommandErrorReasonEnum.CONNECTIVITY_ISSUE
#             assert scan_command_result.error_trace
#             assert scan_command_result.result is None
#
#
# # tests.scanner_tests.test_mass_scanner
# class PluginImplThatCrashesWhenProcessingJobs(ScanCommandImplementation):
#     @classmethod
#     def scan_jobs_for_scan_command(
#         cls: Type[ScanJob], server_info: ServerConnectivityInfo, extra_arguments: Optional[ScanCommandExtraArgumentTypeVar] = None
#     ) -> List[ScanJob]:
#         scan_jobs = [
#             ScanJob(function_to_call=cls._scan_job_work_function, function_arguments=["test"]) for _ in range(5)
#         ]
#         return scan_jobs
#
#
# # tests.scanner_tests.test_mass_scanner
# class PluginImplThatTriggersConnectivityError(ScanCommandImplementation):
#     @classmethod
#     def scan_jobs_for_scan_command(
#         cls: Type[ScanJob], server_info: ServerConnectivityInfo, extra_arguments: Optional[ScanCommandExtraArgumentTypeVar] = None
#     ) -> List[ScanJob]:
#         return [ScanJob(function_to_call=cls._scan_job_work_function, function_arguments=["test"])]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
