# %%
# %load_ext autoreload
# %autoreload 2

import os
import pickle
from pathlib import Path
from typing import *

import pandas as pd
import plotly.express as px

from spot.utils import cst, proj_root, run_long_task, tqdm

os.chdir(proj_root())

datadir = Path(os.getenv("datadir"))
repos_dir = datadir / "SPOT-data/repos"

# %%
from spot.data import SrcDataset

src_datasets_path = datadir / f"SPOT-data/src_datasets"
src_datasets = dict[str, SrcDataset]()
for n in ["train", "valid", "test"]:
    with open(src_datasets_path / f"{n}.pkl", "rb") as f:
        src_datasets[n] = pickle.load(f)
        src_datasets[n].repos_root = repos_dir

# %%
largest_file = max(src_datasets["train"].all_srcs, key=lambda x: len(x.tokenized_code))
print(len(largest_file.tokenized_code))
print(len(largest_file.origin_code))
# Out:
# 471656
# 1061323

# %%
width_list = []
for src in src_datasets["train"].srcs_with_labels():
    lines = src.origin_code.split("\n")
    width = max(len(l) for l in lines)
    width_list.append(width)
px.histogram(pd.DataFrame({"max_width": width_list}), x="max_width")
# Out:
# <div>                            <div id="ea4da86b-cf8b-479b-8cdf-c923c7ad3d2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea4da86b-cf8b-479b-8cdf-c923c7ad3d2c")) {                    Plotly.newPlot(                        "ea4da86b-cf8b-479b-8cdf-c923c7ad3d2c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"max_width=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[88,88,88,88,85,88,88,88,88,88,88,88,98,88,84,88,106,42,171,115,93,73,67,115,70,163,130,60,73,62,99,48,168,66,77,118,119,100,74,49,107,144,62,166,129,122,44,87,87,86,85,84,129,103,119,64,120,100,100,100,100,100,98,100,100,100,100,100,100,98,100,68,100,100,100,99,222,99,106,88,64,80,87,67,57,94,58,95,94,94,76,49,82,80,59,93,92,73,89,89,95,95,95,95,80,95,95,67,66,96,79,50,74,78,80,94,92,98,94,95,84,96,94,76,84,96,93,71,90,94,81,91,49,96,67,205,178,84,69,91,91,91,86,76,77,76,87,76,110,97,91,86,91,321,76,58,66,106,105,82,90,116,108,107,84,93,73,117,84,87,96,109,95,87,86,55,84,88,68,79,112,118,115,118,118,120,120,115,113,106,118,115,113,120,119,105,119,117,120,117,118,118,106,120,92,83,79,74,55,60,73,79,67,69,213,151,118,116,74,72,80,92,83,89,99,66,98,84,94,98,96,59,96,94,94,90,63,84,86,93,106,96,92,98,99,99,95,99,92,59,95,48,91,82,84,87,218,127,116,130,100,149,52,95,105,100,65,94,116,81,110,96,94,132,110,80,109,59,121,92,85,155,125,133,108,78,89,88,98,78,99,99,91,107,78,71,76,78,75,78,78,74,78,99,78,87,77,88,87,87,87,88,74,113,88,88,84,84,81,81,88,128,88,88,121,84,87,88,88,88,88,88,88,88,88,84,85,88,88,86,83,102,84,100,100,100,92,100,111,96,103,145,99,93,106,106,96,94,78,93,102,98,76,74,91,92,99,98,78,87,97,138,85,84,91,88,91,77,109,78,100,123,123,89,100,104,160,92,95,100,186,94,85,84,79,110,115,84,99,102,100,88,96,126,99,99,97,77,88,98,174,63,71,80,81,71,86,51,303,71,99,97,98,99,90,93,92,99,96,99,99,99,102,96,99,87,87,88,87,86,61,88,83,80,88,72,56,51,49,79,66,73,65,78,65,81,87,65,65,81,77,57,76,66,66,66,80,84,78,91,98,62,86,87,68,54,86,82,38,46,81,23,83,32,71,74,88,95,80,79,97,84,76,78,85,90,67,79,93,114,87,75,64,80,72,75,80,76,80,72,71,65,77,67,74,193,76,75,131,111,107,99,114,100,77,75,90,63,78,79,79,75,74,81,80,80,133,73,85,104,79,79,85,94,79,80,88,77,98,80,83,84,79,79,67,71,79,82,78,86,75,80,78,77,80,97,78,78,79,84,75,70,76,79,99,79,80,156,78,81,72,78,70,76,75,76,78,54,57,60,61,61,54,69,63,54,57,78,58,80,79,58,77,98,79,75,77,78,60,78,103,73,80,54,77,69,64,78,78,96,96,96,92,85,106,102,78,79,81,80,75,54,67,86,76,77,54,72,91,68,79,54,56,86,80,72,54,75,54,97,79,48,80,71,80,76,96,92,105,75,80,79,54,80,95,80,54,77,86,79,70,80,66,97,79,54,96,87,76,77,54,80,97,103,118,80,86,57,94,104,94,71,79,83,67,83,118,79,54,74,80,71,80,62,77,71,57,80,79,76,118,94,94,111,118,89,105,78,76,81,74,77,84,54,54,54,62,65,74,54,109,79,54,114,79,58,96,110,78,74,62,94,104,80,79,59,76,77,79,77,97,91,114,110,72,77,79,77,79,77,89,82,78,54,54,97,78,79,98,93,97,105,79,64,78,79,64,79,76,79,87,81,63,82,79,78,81,71,54,97,78,54,80,73,82,83,54,97,63,91,87,80,54,93,80,56,77,73,71,79,66,71,78,77,78,79,79,75,72,73,77,80,78,70,80,71,78,79,79,80,67,77,76,80,74,80,71,69,80,57,74,68,74,80,64,71,76,74,77,79,72,80,88,94,76,71,71,94,80,79,60,71,71,78,79,74,80,80,75,79,79,80,79,104,95,95,80,80,78,75,66,55,75,60,60,79,84,74,106,69,69,74,87,83,83,126,127,218,69,77,120,120,120,115,108,138,106,107,82,88,85,88,117,88,88,112,94,78,56,86,71,81,87,75,62,113,88,74,78,60,84,77,84,107,120,118,834,323,261,131,101,100,151,100,100,199,100,975,101,317,100,104,3397,182,119,119,116,120,91,91,119,81,78,66,118,110,120,72,102,120,79,72,75,70,70,76,79,79,73,78,75,70,79,77,74,76,37,76,79,79,79,78,79,58,75,79,79,79,77,76,79,76,62,79,72,76,73,74,6 ...

# %%
import torch
from spot.model import ModelWrapper, ModelSPOT

with_margin = True
data_reduction = 1

margin_tag = "with_margin" if with_margin else "no_margin"
data_tag = "data_full" if data_reduction == 1 else f"data_1-{data_reduction}"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
r0_model_name = f"SPOT-R0-{margin_tag}-{data_tag}"
r0_wrapper = ModelWrapper.from_pretrained(
    datadir / f"checkpoints/saved/{r0_model_name}"
)
r0_wrapper.model.to(device)
tokenizer = r0_wrapper.tokenizer

# %%
# Set this to the best ctx_size
best_r0_ctx_factor = 3
r0_wrapper_best = r0_wrapper.scale_ctx_size(best_r0_ctx_factor)

# %%
from spot.utils import TaskLoggingMonitor
from spot.model import CtxArgs, DecodingArgs, ModelSPOT, ModelWrapper, TokenizerSPOT

train_r1 = True

r1_model_name = f"SPOT-R1-{margin_tag}-{data_tag}"

if train_r1:
    r1_model_path = "Salesforce/codet5-base"
else:
    r1_model_path = datadir / f"checkpoints/saved/{r1_model_name}"

r1_model: ModelSPOT = ModelSPOT.from_pretrained(r1_model_path).to(device)
r1_monitor = TaskLoggingMonitor("R1")
r1_args = DecodingArgs(
    sampling_batch_size=512,
    ctx_args=CtxArgs(
        ctx_size=512,
        ctx_margin=128,
        types_in_ctx=False,
    ),
    max_workers=20,
)
r1_wrapper = ModelWrapper(r1_model, tokenizer, r1_args, r1_monitor).scale_ctx_size(2)
# Out:
# /home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1402: UserWarning: positional arguments and argument "destination" are deprecated. nn.Module.state_dict will not accept them in the future. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(

# %%
import pickle

from spot.data import ChunkedDataset, save_datasets
from spot.utils import PickleCache

test_r1_generation = False
use_file_level_feedback = False

feedback_tag = "iso_file"  # "per_file" if use_file_level_feedback else "per_project"

r1_cache = PickleCache(datadir / f"cache/r1_src_datasets-{test_r1_generation}")

with run_long_task("Generating R1 datasets", notify=False):
    r1_src_datasets = dict()
    for name in ["test", "valid", "train"]:
        print("Working on:", name)
        r0_src = src_datasets[name]
        if test_r1_generation:
            r0_src = SrcDataset(r0_src.srcs_with_labels()[:16], r0_src.repos_root)
        _, r0_data, r0_preds = r1_cache.cached(
            f"eval_r0/{name}",
            lambda: r0_wrapper_best.eval_on_dataset(r0_src, tqdm_args={"leave": False}),
        )
        r1_src_datasets[name] = r1_cache.cached(
            f"r1_src_datasets/{name}",
            lambda: r1_wrapper.generate_r1_srcs(
                r0_src,
                r0_data,
                r0_preds,
                tqdm_args={"leave": False},
            ),
        )
# Out:
# Working on: test
# processing chunks:   0%|          | 0/1896 [00:00<?, ?it/s]
# predict:   0%|          | 0/1624 [00:00<?, ?it/s]
# type_check_src:   0%|          | 0/891 [00:00<?, ?it/s]
# feedbacks_to_tokenized_src:   0%|          | 0/891 [00:00<?, ?it/s]
# Working on: valid
# processing chunks:   0%|          | 0/2536 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jiayi/Projects/SPOT/scripts/train_spot.ipynb Cell 9' in <cell line: 14>()
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=18'>19</a> if test_r1_generation:
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=19'>20</a>     r0_src = SrcDataset(r0_src.srcs_with_labels()[:16], r0_src.repos_root)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=20'>21</a> _, r0_data, r0_preds = r1_cache.cached(
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=21'>22</a>     f"eval_r0/{name}",
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=22'>23</a>     lambda: r0_wrapper_best.eval_on_dataset(r0_src, tqdm_args={"leave": False}),
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=23'>24</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=24'>25</a> r1_src_datasets[name] = r1_cache.cached(
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=25'>26</a>     f"r1_src_datasets/{name}",
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=26'>27</a>     lambda: r1_wrapper.generate_r1_srcs(
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=31'>32</a>     ),
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=32'>33</a> )
#
# File ~/Projects/SPOT/src/spot/utils.py:329, in PickleCache.cached(self, rel_path, func)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/utils.py?line=326'>327</a> path = self.cache_dir / rel_path
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/utils.py?line=327'>328</a> if not path.exists():
# --> <a href='file:///home/jiayi/Projects/SPOT/src/spot/utils.py?line=328'>329</a>     value = func()
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/utils.py?line=329'>330</a>     path.parent.mkdir(parents=True, exist_ok=True)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/utils.py?line=330'>331</a>     logging.info("Saving to cache: %s", path)
#
# /home/jiayi/Projects/SPOT/scripts/train_spot.ipynb Cell 9' in <lambda>()
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=18'>19</a> if test_r1_generation:
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=19'>20</a>     r0_src = SrcDataset(r0_src.srcs_with_labels()[:16], r0_src.repos_root)
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=20'>21</a> _, r0_data, r0_preds = r1_cache.cached(
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=21'>22</a>     f"eval_r0/{name}",
# ---> <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=22'>23</a>     lambda: r0_wrapper_best.eval_on_dataset(r0_src, tqdm_args={"leave": False}),
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=23'>24</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=24'>25</a> r1_src_datasets[name] = r1_cache.cached(
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=25'>26</a>     f"r1_src_datasets/{name}",
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=26'>27</a>     lambda: r1_wrapper.generate_r1_srcs(
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=31'>32</a>     ),
#      <a href='vscode-notebook-cell://ssh-remote%2Butopia3/home/jiayi/Projects/SPOT/scripts/train_spot.ipynb#ch0000011vscode-remote?line=32'>33</a> )
#
# File ~/Projects/SPOT/src/spot/model.py:129, in ModelWrapper.eval_on_dataset(self, src_data, tqdm_args)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=124'>125</a> def eval_on_dataset(
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=125'>126</a>     self, src_data: SrcDataset, tqdm_args={}
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=126'>127</a> ) -> tuple[dict, ChunkedDataset, list[list[PythonType]]]:
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=127'>128</a>     """Convinient method to preprocess the src according to the model's ctx_args and evaluate the (R0) accuracy."""
# --> <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=128'>129</a>     data = src_data.to_chunks(
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=129'>130</a>         self.tokenizer,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=130'>131</a>         self.args.ctx_args,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=131'>132</a>         max_workers=self.args.max_workers,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=132'>133</a>         tqdm_args=tqdm_args,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=133'>134</a>     )
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=134'>135</a>     preds = self.predict(data, tqdm_args=tqdm_args)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/model.py?line=135'>136</a>     accs = preds_to_accuracies(preds, data)
#
# File ~/Projects/SPOT/src/spot/data.py:347, in SrcDataset.to_chunks(self, tokenizer, ctx_args, max_workers, tqdm_args)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=338'>339</a> def to_chunks(
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=339'>340</a>     self,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=340'>341</a>     tokenizer: TokenizerSPOT,
#    (...)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=343'>344</a>     tqdm_args: dict = {},
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=344'>345</a> ) -> "ChunkedDataset":
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=345'>346</a>     srcs = self.srcs_with_labels()
# --> <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=346'>347</a>     chunks = chunk_srcs(
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=347'>348</a>         self.repos_root,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=348'>349</a>         srcs,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=349'>350</a>         tokenizer,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=350'>351</a>         ctx_args,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=351'>352</a>         max_workers=max_workers,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=352'>353</a>         tqdm_args=tqdm_args,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=353'>354</a>     )
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=354'>355</a>     chunks.verify_labels(self, tokenizer)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=355'>356</a>     return chunks
#
# File ~/Projects/SPOT/src/spot/data.py:291, in chunk_srcs(repos_root, srcs, tokenizer, ctx_args, max_workers, tqdm_args)
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=287'>288</a> stride = ctx_size - 2 * ctx_margin
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=289'>290</a> chunk_tks = [all_tks[i : i + ctx_size] for i in range(0, len(all_tks), stride)]
# --> <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=290'>291</a> chunk_outputs = process_map(
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=291'>292</a>     helper.process_chunk,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=292'>293</a>     chunk_tks,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=293'>294</a>     desc="processing chunks",
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=294'>295</a>     max_workers=max_workers,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=295'>296</a>     chunksize=max(1, len(chunk_tks) // (8 * max_workers)),
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=296'>297</a>     **tqdm_args,
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=297'>298</a> )
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=299'>300</a> chunks: dict[str, list] = {
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=300'>301</a>     "input_ids": [],
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=301'>302</a>     "labels": [],
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=302'>303</a> }
#     <a href='file:///home/jiayi/Projects/SPOT/src/spot/data.py?line=303'>304</a> chunks_info: list[SrcChunkInfo] = []
#
# File ~/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py:130, in process_map(fn, *iterables, **tqdm_kwargs)
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py?line=127'>128</a>     tqdm_kwargs = tqdm_kwargs.copy()
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py?line=128'>129</a>     tqdm_kwargs["lock_name"] = "mp_lock"
# --> <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py?line=129'>130</a> return _executor_map(ProcessPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py:76, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py?line=73'>74</a>     map_args.update(chunksize=chunksize)
#      <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py?line=74'>75</a> with PoolExecutor(**pool_kwargs) as ex:
# ---> <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/contrib/concurrent.py?line=75'>76</a>     return list(tqdm_class(ex.map(fn, *iterables, **map_args), **kwargs))
#
# File ~/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py:258, in tqdm_notebook.__iter__(self)
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py?line=255'>256</a> try:
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py?line=256'>257</a>     it = super(tqdm_notebook, self).__iter__()
# --> <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py?line=257'>258</a>     for obj in it:
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py?line=258'>259</a>         # return super(tqdm...) will not catch exception
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py?line=259'>260</a>         yield obj
#     <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/notebook.py?line=260'>261</a> # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py?line=1191'>1192</a> time = self._time
#    <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py?line=1193'>1194</a> try:
# -> <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py?line=1194'>1195</a>     for obj in iterable:
#    <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py?line=1195'>1196</a>         yield obj
#    <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py?line=1196'>1197</a>         # Update and possibly print the progressbar.
#    <a href='file:///home/jiayi/Projects/SPOT/.venv/lib/python3.10/site-packages/tqdm/std.py?line=1197'>1198</a>         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py:567, in _chain_from_iterable_of_lists(iterable)
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=560'>561</a> def _chain_from_iterable_of_lists(iterable):
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=561'>562</a>     """
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=562'>563</a>     Specialized implementation of itertools.chain.from_iterable.
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=563'>564</a>     Each item in *iterable* should be a list.  This function is
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=564'>565</a>     careful not to keep references to yielded objects.
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=565'>566</a>     """
# --> <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=566'>567</a>     for element in iterable:
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=567'>568</a>         element.reverse()
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/process.py?line=568'>569</a>         while element:
#
# File ~/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py:609, in Executor.map.<locals>.result_iterator()
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=605'>606</a> while fs:
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=606'>607</a>     # Careful not to keep a reference to the popped future
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=607'>608</a>     if timeout is None:
# --> <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=608'>609</a>         yield fs.pop().result()
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=609'>610</a>     else:
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=610'>611</a>         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=437'>438</a> elif self._state == FINISHED:
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=438'>439</a>     return self.__get_result()
# --> <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=440'>441</a> self._condition.wait(timeout)
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=442'>443</a> if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/concurrent/futures/_base.py?line=443'>444</a>     raise CancelledError()
#
# File ~/anaconda3/envs/py3.10/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/threading.py?line=317'>318</a> try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/threading.py?line=318'>319</a>     if timeout is None:
# --> <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/threading.py?line=319'>320</a>         waiter.acquire()
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/threading.py?line=320'>321</a>         gotit = True
#     <a href='file:///home/jiayi/anaconda3/envs/py3.10/lib/python3.10/threading.py?line=321'>322</a>     else:
#
# KeyboardInterrupt:

# %%
import wandb
from spot.model import ModelTrainingArgs

r1_train_args = ModelTrainingArgs(
    train_batch_size=38 // 8,
    eval_batch_size=256 // 8,
    max_epochs=3,
)

if train_r1:
    r1_chunks: dict[str, ChunkedDataset] = {}
    with run_long_task("Preparing R1 chunked datasets", notify=False):
        for n in ["valid", "train"]:
            r1_chunks[n] = r1_src_datasets[n].to_chunks(
                tokenizer, r1_wrapper.args.ctx_args, max_workers=20
            )

    r1_trainer = r1_wrapper.build_trainer(
        datadir / "checkpoints" / r1_model_name,
        r1_train_args,
        dataset=r1_chunks["train"].data,
        eval_dataset=r1_chunks["valid"].data,
    )

    wandb.init(
        project=r1_model_name,
        dir=str(datadir),
        config={"r1_decoding_args": r1_args, "r1_train_args": r1_train_args},
    )

    with run_long_task(f"Training {r1_model_name}"):
        init_perf = r1_trainer.evaluate(max_length=r1_args.generation_max_length)
        print("initial performance:", init_perf)
        r1_trainer.train()

    wandb.log({"time_stats": r1_monitor.timer.total_times()})

    final_perf = r1_trainer.evaluate(max_length=r1_args.generation_max_length)
    print("final performance:", final_perf)
    wandb.finish()

    r1_wrapper.save_pretrained(datadir / f"checkpoints/saved/{r1_model_name}")
# Out:
# PyTorch: setting up devices
# Using amp half precision backend

# %%
from spot.data import preds_to_accuracies, pretty_print_accuracies
from spot.visualization import display_code_sequence, visualize_batch

r1_wrapper_test = r1_wrapper
r1_accs, r1_data, r1_preds = r1_wrapper_test.eval_on_dataset(r1_src_datasets["test"])
pretty_print_accuracies(r1_accs)

display_code_sequence(
    [
        visualize_batch(
            r1_data,
            i,
            r1_preds,
            tokenizer,
            r1_wrapper_test.args.ctx_args,
        )
        for i in range(min(16, len(r1_data.chunks_info)))
    ]
)
# Out:
# processing chunks:   0%|          | 0/26 [00:00<?, ?it/s]
# predict:   0%|          | 0/15 [00:00<?, ?it/s]
# partial_acc: 75.00%
# partial_acc_wo_any: 75.00%
# partial_accs:
#    FuncArg: 75.00%
#    FuncReturn: 78.57%
#    LocalVar: 50.00%
# full_acc: 57.50%
# full_accs:
#    FuncArg: 50.00%
#    FuncReturn: 71.43%
#    LocalVar: 50.00%
# n_labels: 40
# Tab(children=(HTML(value="<pre style='line-height: 1.2; padding: 10px; color: rgb(212,212,212); background-col…
