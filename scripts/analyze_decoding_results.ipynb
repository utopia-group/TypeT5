# %%
# %load_ext autoreload
# %autoreload 2

# first, load the trained model
import os
import torch
from typing import *

from spot.model import ModelWrapper
from spot.utils import get_model_dir, proj_root

os.chdir(proj_root())

# gpu_id = 1
# modeldir = get_model_dir()

model_name="model-v5--TrainingConfig(drop_env_types=False)"
# dataset_name = "ManyTypes4Py"
dataset_name = "SPOT-src"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from spot.utils import *
from spot.function_dataset import data_project_from_dir

# load test projects
repos_dir = get_dataset_dir(dataset_name) / "repos" / "test"
test_repo_paths = [f for f in repos_dir.iterdir() if f.is_dir()]
test_projects = pmap(
    data_project_from_dir,
    test_repo_paths,
    desc="Loading test projects",
)
assert len(test_projects) > 0
# Out:
# Loading test projects: 100%|██████████| 1/1 [00:06<00:00,  6.32s/it]

# %%
from spot.function_decoding import DecodingOrders, EvalResult

results_dir = get_eval_dir(dataset_name, model_name)

decode_orders = {
    "no-neighbors": DecodingOrders.IndependentOrder(),
    "non-incr": DecodingOrders.IndependentOrder(),
    "random": DecodingOrders.RandomOrder(),
    "double-traversal": DecodingOrders.DoubleTraversal(),
    "callee2caller": DecodingOrders.Callee2Caller(),
    "caller2callee": DecodingOrders.Caller2Callee(),
}

evals = dict[str, EvalResult]()

for oname in tqdm(decode_orders, desc="Loading evaluation results"):
    evals[oname] = pickle_load(results_dir / f"{oname}-EvalResult.pkl")
# Out:
# Loading evaluation results: 100%|██████████| 6/6 [00:00<00:00,  8.11it/s]

# %%
from prettytable import PrettyTable
import prettytable as pt
from spot.type_env import AccuracyMetric

common_type_names = ModelWrapper.load_common_type_names(get_model_dir() / model_name)
metrics = AccuracyMetric.default_metrics(common_type_names)
results_table = PrettyTable()
results_table.field_names = ["order", *(m.name for m in metrics)]
results_table.align = "r"
results_table.set_style(pt.SINGLE_BORDER)
results_table.float_format = ".4"

for oname in decode_orders:
    accs = [evals[oname].error_analysis(None, metric).accuracies[metric.name].acc for metric in metrics]
    results_table.add_row([oname, *accs])

print(results_table)
write_file(results_dir / "comparison.txt", results_table.get_string())
# Out:
# ┌──────────────────┬───────────┬────────┬──────────┐
# │            order │ plain_acc │    acc │ base_acc │
# ├──────────────────┼───────────┼────────┼──────────┤
# │     no-neighbors │    0.5046 │ 0.5117 │   0.6017 │
# │         non-incr │    0.5905 │ 0.6092 │   0.7048 │
# │           random │    0.5932 │ 0.6139 │   0.7151 │
# │ double-traversal │    0.6060 │ 0.6326 │   0.7451 │
# │    callee2caller │    0.6060 │ 0.6317 │   0.7488 │
# │    caller2callee │    0.5850 │ 0.6111 │   0.7095 │
# └──────────────────┴───────────┴────────┴──────────┘

# %%
import pandas as pd
from spot.type_env import AccuracyMetric


common_type_names = ModelWrapper.load_common_type_names(get_model_dir() / model_name)
metrics = AccuracyMetric.default_metrics(common_type_names)
strategy2acc = {
    s: evals[s].error_analysis(None, acc_metric).accuracies[acc_metric.name]
    for s in evals
}

# %%
projects = [p.root_dir.name for p in test_projects]
acc_metric = AccuracyMetric(common_type_names)

strategies_to_show = ["no-neighbors", "non-incr", "double-traversal"]
strategy2accs = {
    s: [
        evals[s].error_analysis(pname, acc_metric).accuracies[acc_metric.name]
        for pname in projects
    ]
    for s in strategies_to_show
}

n_annots = [
    sum(e.get_signature().n_annots() for e in p.all_elems()) for p in test_projects
]
# n_labels = [
#     sum(e.get_signature().n_annotated() for e in p.all_elems()) for p in test_projects
# ]
n_labels = [x.n_total for x in strategy2accs[strategies_to_show[0]]]
label_sizes = [
    evals[strategies_to_show[0]]
    .error_analysis(pname, acc_metric)
    .accuracies[f"{acc_metric.name}_label_size"]
    for pname in projects
]

label_rates = [a / b for a, b in zip(n_labels, n_annots)]

df = pd.DataFrame(
    {
        "project": projects,
        **{n: [x.acc for x in xs] for n, xs in strategy2accs.items()},
        "label_size": label_sizes,
        "label_rate": label_rates,
        "labels": n_labels,
    }
)
df_sorted = df.sort_values(by=["labels"], ascending=False)
df_sorted
# Out:
#                                    project  no-neighbors  non-incr  \
# 17                 basilisp-lang__basilisp      0.588235  0.623398
# 29                      nabla-c0d3__sslyze      0.712009  0.752391
# 27                   kornicameister__axion      0.490960  0.509040
# 1        scalableminds__webknossos-connect      0.675719  0.750799
# 30               rakitaj__daily-programmer      0.737037  0.742593
# 42                        seattleflu__id3c      0.738189  0.832677
# 13    marcosschroh__dataclasses-avroschema      0.505695  0.503417
# 25                         nubark__instark      0.816537  0.857881
# 48           everyclass__everyclass-server      0.723724  0.789790
# 35  lucaswerkmeister__tool-quickcategories      0.758065  0.787097
# 6                    flopp__GpxTrackPoster      0.549815  0.656827
# 18             paulcwatts__drf-json-schema      0.659091  0.643939
# 41                webrecorder__browsertrix      0.613281  0.687500
# 49                       knowark__estimark      0.863071  0.842324
# 38                    futursolo__magichttp      0.509009  0.626126
# 20                    AxelVoitier__lookups      0.342466  0.415525
# 22                        joshtemple__lkml      0.731707  0.765854
# 45                             jreese__aql      0.548718  0.574359
# 34                      sonic182__aiosonic      0.839378  0.839378
# 43                    TomerFi__aioswitcher      0.726316  0.810526
# 26                    albertyw__git-browse      0.594444  0.716667
# 23                kitsuyui__bamboo-crawler      0.633136  0.644970
# 9            reddit__baseplate.py-upgrader      0.754839  0.761290
# 11                linw1995__data_extractor      0.600000  0.676923
# 33                        ocf__slackbridge      0.693548  0.709677
# 28                        payscale__fables      0.733871  0.790323
# 5              road-master__video-archiver      0.853659  0.910569
# 19      ShadowTemplate__beautiful-python-3      0.899160  0.957983
# 39              ActivityWatch__aw-research      0.820513  0.837607
# 2                  flopp__unicode-explorer      0.820513  0.854701
# 14               antonagestam__collectfast      0.689655  0.715517
# 0                       srittau__FakeSMTPd      0.836207  0.879310
# 10        typeddjango__pytest-mypy-plugins      0.756522  0.782609
# 21    Gerschtli__teamspeak-update-notifier      0.600000  0.666667
# 16                 brettkromkamp__topic-db      0.847619  0.876190
# 37                   ClearcodeHQ__mirakuru      0.690722  0.742268
# 32                          JakobGM__quelf      0.543478  0.565217
# 7                   boompig__book-classics      0.905882  0.941176
# 40                    lebrice__blurred-GAN      0.701299  0.623377
# 24          amplify-education__python-hcl2      0.630137  0.643836
# 47                          cliffxuan__mew      0.763889  0.833333
# 12                  albertyw__albertyw.com      0.528571  0.628571
# 36                         ohjames__babies      0.850746  0.880597
# 15                  ammarnajjar__pautomate      0.851852  0.870370
# 4                      jelford__webwatcher      0.765957  0.765957
# 8                dropbox__sqlalchemy-stubs      0.595238  0.666667
# 44                    jfly__jfly.github.io      0.696970  0.818182
# 3                    eirannejad__calcatime      0.468750  0.531250
# 31          silasary__discord_connotations      0.615385  0.692308
# 46           yeraydiazdiaz__wait_for_it.py      1.000000  1.000000
#
#     double-traversal  label_size  label_rate  labels
# 17          0.619454    1.243181    0.526926    3043
# 29          0.763018    1.269926    0.568924     941
# 27          0.454798    1.624478    0.630149     719
# 1           0.776358    1.209265    0.830239     626
# 30          0.766667    1.527778    0.500928     540
# 42          0.852362    1.206693    0.442509     508
# 13          0.476082    1.473804    0.427875     439
# 25          0.857881    1.180879    0.346774     387
# 48          0.747748    1.201201    0.372900     333
# 35          0.764516    1.400000    0.658174     310
# 6           0.715867    1.247232    0.654589     271
# 18          0.693182    1.409091    0.528000     264
# 41          0.687500    1.175781    0.307323     256
# 49          0.846473    1.327801    0.335655     241
# 38          0.698198    1.148649    0.354067     222
# 20          0.378995    1.593607    0.334351     219
# 22          0.770732    1.434146    0.395753     205
# 45          0.564103    1.456410    0.437220     195
# 34          0.792746    1.134715    0.291982     193
# 43          0.894737    1.142105    0.336283     190
# 26          0.727778    1.077778    0.462725     180
# 23          0.633136    1.751479    0.645038     169
# 9           0.812903    1.264516    0.430556     155
# 11          0.653846    1.423077    0.230906     130
# 33          0.774194    1.370968    0.576744     124
# 28          0.750000    1.677419    0.366864     124
# 5           0.918699    1.162602    0.416949     123
# 19          0.941176    1.142857    0.328729     119
# 39          0.820513    1.675214    0.366771     117
# 2           0.923077    1.145299    0.576355     117
# 14          0.758621    1.258621    0.515556     116
# 0           0.896552    1.232759    0.348348     116
# 10          0.782609    1.695652    0.732484     115
# 21          0.685714    1.161905    0.549738     105
# 16          0.923810    1.095238    0.363322     105
# 37          0.773196    1.855670    0.383399      97
# 32          0.554348    1.184783    0.528736      92
# 7           0.941176    1.270588    0.586207      85
# 40          0.688312    1.077922    0.184211      77
# 24          0.821918    1.027397    0.730000      73
# 47          0.777778    1.027778    0.369231      72
# 12          0.642857    1.600000    0.374332      70
# 36          0.880597    1.358209    0.325243      67
# 15          0.925926    1.388889    0.504673      54
# 4           0.765957    1.319149    0.218605      47
# 8           0.642857    1.261905    0.608696      42
# 44          0.969697    1.151515    0.237410      33
# 3           0.500000    1.937500    0.800000      32
# 31          0.692308    1.461538    0.270833      13
# 46          1.000000    1.333333    0.375000       6

# %%
df
# Out:
#                                    project  no-neighbors  non-incr  \
# 0                       srittau__FakeSMTPd      0.836207  0.879310
# 1        scalableminds__webknossos-connect      0.675719  0.750799
# 2                  flopp__unicode-explorer      0.820513  0.854701
# 3                    eirannejad__calcatime      0.468750  0.531250
# 4                      jelford__webwatcher      0.765957  0.765957
# 5              road-master__video-archiver      0.853659  0.910569
# 6                    flopp__GpxTrackPoster      0.549815  0.656827
# 7                   boompig__book-classics      0.905882  0.941176
# 8                dropbox__sqlalchemy-stubs      0.595238  0.666667
# 9            reddit__baseplate.py-upgrader      0.754839  0.761290
# 10        typeddjango__pytest-mypy-plugins      0.756522  0.782609
# 11                linw1995__data_extractor      0.600000  0.676923
# 12                  albertyw__albertyw.com      0.528571  0.628571
# 13    marcosschroh__dataclasses-avroschema      0.505695  0.503417
# 14               antonagestam__collectfast      0.689655  0.715517
# 15                  ammarnajjar__pautomate      0.851852  0.870370
# 16                 brettkromkamp__topic-db      0.847619  0.876190
# 17                 basilisp-lang__basilisp      0.588235  0.623398
# 18             paulcwatts__drf-json-schema      0.659091  0.643939
# 19      ShadowTemplate__beautiful-python-3      0.899160  0.957983
# 20                    AxelVoitier__lookups      0.342466  0.415525
# 21    Gerschtli__teamspeak-update-notifier      0.600000  0.666667
# 22                        joshtemple__lkml      0.731707  0.765854
# 23                kitsuyui__bamboo-crawler      0.633136  0.644970
# 24          amplify-education__python-hcl2      0.630137  0.643836
# 25                         nubark__instark      0.816537  0.857881
# 26                    albertyw__git-browse      0.594444  0.716667
# 27                   kornicameister__axion      0.490960  0.509040
# 28                        payscale__fables      0.733871  0.790323
# 29                      nabla-c0d3__sslyze      0.712009  0.752391
# 30               rakitaj__daily-programmer      0.737037  0.742593
# 31          silasary__discord_connotations      0.615385  0.692308
# 32                          JakobGM__quelf      0.543478  0.565217
# 33                        ocf__slackbridge      0.693548  0.709677
# 34                      sonic182__aiosonic      0.839378  0.839378
# 35  lucaswerkmeister__tool-quickcategories      0.758065  0.787097
# 36                         ohjames__babies      0.850746  0.880597
# 37                   ClearcodeHQ__mirakuru      0.690722  0.742268
# 38                    futursolo__magichttp      0.509009  0.626126
# 39              ActivityWatch__aw-research      0.820513  0.837607
# 40                    lebrice__blurred-GAN      0.701299  0.623377
# 41                webrecorder__browsertrix      0.613281  0.687500
# 42                        seattleflu__id3c      0.738189  0.832677
# 43                    TomerFi__aioswitcher      0.726316  0.810526
# 44                    jfly__jfly.github.io      0.696970  0.818182
# 45                             jreese__aql      0.548718  0.574359
# 46           yeraydiazdiaz__wait_for_it.py      1.000000  1.000000
# 47                          cliffxuan__mew      0.763889  0.833333
# 48           everyclass__everyclass-server      0.723724  0.789790
# 49                       knowark__estimark      0.863071  0.842324
#
#     double-traversal  label_size  label_rate  labels
# 0           0.896552    1.232759    0.348348     116
# 1           0.776358    1.209265    0.830239     626
# 2           0.923077    1.145299    0.576355     117
# 3           0.500000    1.937500    0.800000      32
# 4           0.765957    1.319149    0.218605      47
# 5           0.918699    1.162602    0.416949     123
# 6           0.715867    1.247232    0.654589     271
# 7           0.941176    1.270588    0.586207      85
# 8           0.642857    1.261905    0.608696      42
# 9           0.812903    1.264516    0.430556     155
# 10          0.782609    1.695652    0.732484     115
# 11          0.653846    1.423077    0.230906     130
# 12          0.642857    1.600000    0.374332      70
# 13          0.476082    1.473804    0.427875     439
# 14          0.758621    1.258621    0.515556     116
# 15          0.925926    1.388889    0.504673      54
# 16          0.923810    1.095238    0.363322     105
# 17          0.619454    1.243181    0.526926    3043
# 18          0.693182    1.409091    0.528000     264
# 19          0.941176    1.142857    0.328729     119
# 20          0.378995    1.593607    0.334351     219
# 21          0.685714    1.161905    0.549738     105
# 22          0.770732    1.434146    0.395753     205
# 23          0.633136    1.751479    0.645038     169
# 24          0.821918    1.027397    0.730000      73
# 25          0.857881    1.180879    0.346774     387
# 26          0.727778    1.077778    0.462725     180
# 27          0.454798    1.624478    0.630149     719
# 28          0.750000    1.677419    0.366864     124
# 29          0.763018    1.269926    0.568924     941
# 30          0.766667    1.527778    0.500928     540
# 31          0.692308    1.461538    0.270833      13
# 32          0.554348    1.184783    0.528736      92
# 33          0.774194    1.370968    0.576744     124
# 34          0.792746    1.134715    0.291982     193
# 35          0.764516    1.400000    0.658174     310
# 36          0.880597    1.358209    0.325243      67
# 37          0.773196    1.855670    0.383399      97
# 38          0.698198    1.148649    0.354067     222
# 39          0.820513    1.675214    0.366771     117
# 40          0.688312    1.077922    0.184211      77
# 41          0.687500    1.175781    0.307323     256
# 42          0.852362    1.206693    0.442509     508
# 43          0.894737    1.142105    0.336283     190
# 44          0.969697    1.151515    0.237410      33
# 45          0.564103    1.456410    0.437220     195
# 46          1.000000    1.333333    0.375000       6
# 47          0.777778    1.027778    0.369231      72
# 48          0.747748    1.201201    0.372900     333
# 49          0.846473    1.327801    0.335655     241

# %%
df_sorted.to_csv(proj_root() / "data" / "accs_by_project.csv")

# %%
ex_proj = test_projects[17]
print("Project location:", ex_proj.root_dir)

evalr = evals["double-traversal"]
pid = evalr.project_roots.index(ex_proj.root_dir)
ex_analysis = evalr.error_analysis(pid, acc_metric)
ex_errors = ex_analysis.errors[ex_proj.root_dir.name]
ex_rollout = evalr.predictions[pid]

print("Number of errors:", len(ex_errors))
# Out:
# Project location: /mnt/data0/jiayi/SPOT/datasets/ManyTypes4Py/repos/test/basilisp-lang__basilisp
# Number of errors: 1158

# %%
# under predicted types sorted by frequency
under_pred_types = Counter()
over_predicted_types = Counter()
for pred in ex_errors:
    under_pred_types[acc_metric.process_type(pred.expected)] += 1
    over_predicted_types[acc_metric.process_type(pred.predicted)] += 1

print("Under-predicted types:")
display(under_pred_types.most_common(10))
print("Over-predicted types:")
display(over_predicted_types.most_common(10))
# Out:
# Under-predicted types:
# [(ty'GeneratorContext', 81),
#  (ty'runtime.Namespace', 63),
#  (ty'sym.Symbol', 59),
#  (ty'AnalyzerContext', 58),
#  (ty'ISeq', 50),
#  (ty'IPersistentVector[LispForm]', 46),
#  (ty'Sequence[kw.Keyword]', 45),
#  (ty'IPersistentMap', 34),
#  (ty'str', 31),
#  (ty'atom.Atom[NamespaceMap]', 17)]
# Over-predicted types:
# [(ty'vec.PersistentVector', 99),
#  (ty'SpecialFormNode', 97),
#  (ty'str', 70),
#  (ty'ast.Context', 62),
#  (ty'int', 52),
#  (ty'ast.AST', 44),
#  (ty'Node', 37),
#  (ty'T', 30),
#  (ty'sym.Symbol', 28),
#  (ty'NamespaceMap', 18)]

# %%
from spot.static_analysis import ProjectPath

error_id = 0
pred = ex_errors[error_id]
print("----------------------")
print("Elem Path:", pred.path)
print("Type Index:", pred.index)
evalr.inspect_elem(pid, pred.path)
# evalr.inspect_elem(pid, ProjectPath.from_str("runner/Runner.run_command"))
# Out:
# ----------------------
# Elem Path: command/Command.apply
# Type Index: 2
# Expected:  MethodSig((wikitext: str, category_info: CategoryInfo) -> Tuple[str, List[Tuple[Action, bool]]])
# Predicted: MethodSig((wikitext: str, category_info: CategoryInfo) -> Tuple[str, List[Action]])
# Code:
# import datetime
# from page import Page
# from siteinfo import CategoryInfo
# from abc import ABC, abstractmethod
# from dataclasses import dataclass
# from action import Action
# from typing import List, Optional, Tuple, Union
# @dataclass(...)
# class Command:
#    ...
# @dataclass(...)
# class CommandRecord(ABC):
#    ...
# class CommandPlan(CommandRecord):
#    ...
# class CommandPending(CommandRecord):
#    ...
# class CommandFinish(CommandRecord):
#    ...
# class CommandSuccess(CommandFinish):
#    ...
# @dataclass(...)
# class CommandEdit(CommandSuccess):
#    ...
# @dataclass(...)
# class CommandNoop(CommandSuccess):
#    ...
# class CommandFailure(CommandFinish):
#    ...
# @dataclass(...)
# class CommandPageMissing(CommandFailure):
#    ...
# @dataclass(...)
# class CommandTitleInvalid(CommandFailure):
#    ...
# @dataclass(...)
# class CommandTitleInterwiki(CommandFailure):
#    ...
# @dataclass(...)
# class CommandPageProtected(CommandFailure):
#    ...
# class CommandEditConflict(CommandFailure):
#    ...
# @dataclass(...)
# class CommandMaxlagExceeded(CommandFailure):
#    ...
# @dataclass(...)
# class CommandBlocked(CommandFailure):
#    ...
# @dataclass(...)
# class CommandWikiReadOnly(CommandFailure):
#    ...
#
# # Used:
# # action
# class Action(ABC):
#     @abstractmethod
#     def apply(self, wikitext: Wikilink, category_info: CategoryInfo) -> Wikilink:...
#
#
# # action
# @dataclass
# class RemoveCategoryAction(CategoryAction):
#     def apply(self, wikitext: str, category_info: CategoryInfo) -> str:...
#
#
# # action
# @dataclass
# class AddCategoryAction(CategoryAction):
#     def apply(self, wikitext: str, category_info: CategoryInfo) -> str:...
#
#
# # command
# @dataclass(frozen=True)
# class Command:
#     actions: List[Action]
#
# # Target:
# # command
# @dataclass(frozen=True)
# class Command:
#     def apply(self, wikitext: <extra_id_0>, category_info: <extra_id_1>) -> <extra_id_2>:
#         actions = []
#
#         for action in self.actions:
#             new_wikitext = action.apply(wikitext, category_info)
#             actions.append((action, wikitext == new_wikitext))
#             wikitext = new_wikitext
#
#         return wikitext, actions
#
#
# # Users:
