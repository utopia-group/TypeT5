# %%
# %load_ext autoreload
# %autoreload 2

# first, load the trained model
import os
import torch
from typing import *

from spot.model import ModelWrapper
from spot.utils import get_model_dir, proj_root

os.chdir(proj_root())

# gpu_id = 1
# modeldir = get_model_dir()

model_name="model-v6--TrainingConfig(drop_env_types=False)"
dataset_name = "ManyTypes4Py"
# dataset_name = "SPOT-src"

# %%
from spot.utils import *
from spot.function_dataset import data_project_from_dir

# load test projects
repos_dir = get_dataset_dir(dataset_name) / "repos" / "test"
test_repo_paths = [f for f in repos_dir.iterdir() if f.is_dir()]
test_projects = pmap(
    data_project_from_dir,
    test_repo_paths,
    desc="Loading test projects",
)
assert len(test_projects) > 0
# Out:
# Loading test projects: 100%|██████████| 50/50 [00:19<00:00,  2.53it/s]

# %%
from spot.function_decoding import DecodingOrders, EvalResult
import re

results_dir = get_eval_dir(dataset_name, model_name)

decode_orders = [m.group(1) for f in results_dir.iterdir() if (m:=re.match(r"(.+)-EvalResult\.pkl", f.name)) is not None]
decode_orders.sort()

evals = dict[str, EvalResult]()

for oname in tqdm(decode_orders, desc="Loading evaluation results"):
    evals[oname] = pickle_load(results_dir / f"{oname}-EvalResult.pkl")
# Out:
# Loading evaluation results: 100%|██████████| 3/3 [00:08<00:00,  2.70s/it]

# %%
from prettytable import PrettyTable
import prettytable as pt
from spot.type_env import AccuracyMetric

common_type_names = ModelWrapper.load_common_type_names(get_model_dir() / model_name)
metrics = AccuracyMetric.default_metrics(common_type_names)
results_table = PrettyTable()
results_table.field_names = ["order", *(m.name for m in metrics)]
results_table.align = "r"
results_table.set_style(pt.SINGLE_BORDER)
results_table.float_format = ".4"

for oname in decode_orders:
    accs = [evals[oname].error_analysis(None, metric).accuracies[metric.name].acc for metric in metrics]
    results_table.add_row([oname, *accs])

print(results_table)
# write_file(results_dir / "comparison.txt", results_table.get_string())
# Out:
# ┌──────────────────┬───────────┬────────┬──────────┐
# │            order │ plain_acc │    acc │ base_acc │
# ├──────────────────┼───────────┼────────┼──────────┤
# │ double-traversal │    0.7158 │ 0.7092 │   0.7717 │
# │         non-incr │    0.7022 │ 0.6951 │   0.7583 │
# │     random-twice │    0.6849 │ 0.6756 │   0.7569 │
# └──────────────────┴───────────┴────────┴──────────┘

# %%
projects = [p.root_dir.name for p in test_projects]
acc_metric = AccuracyMetric(common_type_names)

strategies_to_show = ["non-incr", "random-twice", "double-traversal"]
strategy2accs = {
    s: [
        evals[s].error_analysis(pname, acc_metric).accuracies[acc_metric.name]
        for pname in projects
    ]
    for s in strategies_to_show
}

n_annots = [
    sum(e.get_signature().n_annots() for e in p.all_elems()) for p in test_projects
]
# n_labels = [
#     sum(e.get_signature().n_annotated() for e in p.all_elems()) for p in test_projects
# ]
n_labels = [x.n_total for x in strategy2accs[strategies_to_show[0]]]
label_sizes = [
    evals[strategies_to_show[0]]
    .error_analysis(pname, acc_metric)
    .accuracies[f"{acc_metric.name}_label_size"]
    for pname in projects
]

label_rates = [a / b for a, b in zip(n_labels, n_annots)]

df = pd.DataFrame(
    {
        "project": projects,
        **{n: [x.acc for x in xs] for n, xs in strategy2accs.items()},
        "label_size": label_sizes,
        "label_rate": label_rates,
        "labels": n_labels,
    }
)
df_sorted = df.sort_values(by=["labels"], ascending=False)
df_sorted
# Out:
#                                    project  non-incr  random-twice  \
# 17                 basilisp-lang__basilisp  0.608710      0.492796
# 29                      nabla-c0d3__sslyze  0.777191      0.761352
# 27                   kornicameister__axion  0.488473      0.465418
# 1        scalableminds__webknossos-connect  0.723147      0.736762
# 35  lucaswerkmeister__tool-quickcategories  0.750455      0.772313
# 42                        seattleflu__id3c  0.709324      0.698355
# 30               rakitaj__daily-programmer  0.738889      0.750000
# 25                         nubark__instark  0.887728      0.890339
# 16                 brettkromkamp__topic-db  0.726190      0.693452
# 48           everyclass__everyclass-server  0.777778      0.819820
# 6                    flopp__GpxTrackPoster  0.686347      0.701107
# 13    marcosschroh__dataclasses-avroschema  0.557692      0.542308
# 41                webrecorder__browsertrix  0.730469      0.714844
# 18             paulcwatts__drf-json-schema  0.624506      0.660079
# 49                       knowark__estimark  0.867220      0.896266
# 38                    futursolo__magichttp  0.581081      0.621622
# 20                    AxelVoitier__lookups  0.415525      0.479452
# 22                        joshtemple__lkml  0.751220      0.834146
# 45                             jreese__aql  0.645320      0.704433
# 34                      sonic182__aiosonic  0.803109      0.823834
# 43                    TomerFi__aioswitcher  0.768421      0.842105
# 26                    albertyw__git-browse  0.755556      0.722222
# 23                kitsuyui__bamboo-crawler  0.656805      0.680473
# 9            reddit__baseplate.py-upgrader  0.829268      0.829268
# 11                linw1995__data_extractor  0.653846      0.684615
# 33                        ocf__slackbridge  0.741935      0.750000
# 28                        payscale__fables  0.790323      0.766129
# 5              road-master__video-archiver  0.861789      0.861789
# 19      ShadowTemplate__beautiful-python-3  0.915966      0.915966
# 2                  flopp__unicode-explorer  0.777778      0.863248
# 39              ActivityWatch__aw-research  0.829060      0.837607
# 14               antonagestam__collectfast  0.732759      0.758621
# 0                       srittau__FakeSMTPd  0.870690      0.922414
# 10        typeddjango__pytest-mypy-plugins  0.721739      0.782609
# 21    Gerschtli__teamspeak-update-notifier  0.761905      0.771429
# 37                   ClearcodeHQ__mirakuru  0.773196      0.804124
# 32                          JakobGM__quelf  0.456522      0.456522
# 7                   boompig__book-classics  0.929412      0.929412
# 40                    lebrice__blurred-GAN  0.738095      0.690476
# 24          amplify-education__python-hcl2  0.739726      0.780822
# 47                          cliffxuan__mew  0.704225      0.591549
# 12                  albertyw__albertyw.com  0.671429      0.657143
# 36                         ohjames__babies  0.850746      0.820896
# 15                  ammarnajjar__pautomate  0.907407      0.925926
# 4                      jelford__webwatcher  0.765957      0.744681
# 8                dropbox__sqlalchemy-stubs  0.690476      0.690476
# 44                    jfly__jfly.github.io  0.787879      0.818182
# 3                    eirannejad__calcatime  0.906250      0.906250
# 31          silasary__discord_connotations  0.666667      0.666667
# 46           yeraydiazdiaz__wait_for_it.py  1.000000      1.000000
#
#     double-traversal  label_size  label_rate  labels
# 17          0.617551    1.242633    0.525826    3054
# 29          0.769799    1.269271    0.566049     947
# 27          0.481268    1.644092    0.625789     694
# 1           0.760968    1.242057    0.830402     661
# 35          0.790528    1.510018    0.605292     549
# 42          0.716636    1.208410    0.449466     547
# 30          0.766667    1.527778    0.500928     540
# 25          0.877285    1.172324    0.364762     383
# 16          0.723214    1.145833    0.598930     336
# 48          0.783784    1.201201    0.372900     333
# 6           0.682657    1.247232    0.654589     271
# 13          0.534615    1.353846    0.293123     260
# 41          0.703125    1.175781    0.307323     256
# 18          0.656126    1.403162    0.533755     253
# 49          0.863071    1.327801    0.335655     241
# 38          0.675676    1.148649    0.354067     222
# 20          0.447489    1.593607    0.337442     219
# 22          0.814634    1.434146    0.395753     205
# 45          0.704433    1.438424    0.447137     203
# 34          0.730570    1.134715    0.285503     193
# 43          0.878947    1.142105    0.336283     190
# 26          0.777778    1.077778    0.462725     180
# 23          0.680473    1.751479    0.645038     169
# 9           0.847561    1.250000    0.438503     164
# 11          0.669231    1.423077    0.248092     130
# 33          0.798387    1.370968    0.576744     124
# 28          0.798387    1.677419    0.366864     124
# 5           0.869919    1.162602    0.416949     123
# 19          0.915966    1.142857    0.328729     119
# 2           0.863248    1.145299    0.576355     117
# 39          0.854701    1.675214    0.366771     117
# 14          0.758621    1.258621    0.515556     116
# 0           0.931034    1.232759    0.348348     116
# 10          0.782609    1.695652    0.732484     115
# 21          0.857143    1.161905    0.549738     105
# 37          0.793814    1.855670    0.383399      97
# 32          0.467391    1.184783    0.528736      92
# 7           0.929412    1.270588    0.586207      85
# 40          0.678571    1.071429    0.188764      84
# 24          0.821918    1.027397    0.730000      73
# 47          0.591549    1.028169    0.365979      71
# 12          0.657143    1.600000    0.374332      70
# 36          0.820896    1.358209    0.325243      67
# 15          0.925926    1.388889    0.504673      54
# 4           0.744681    1.319149    0.218605      47
# 8           0.690476    1.261905    0.608696      42
# 44          0.818182    1.151515    0.237410      33
# 3           0.906250    1.937500    0.800000      32
# 31          0.666667    1.400000    0.288462      15
# 46          1.000000    1.333333    0.375000       6

# %%
df
# Out:
#                                    project  non-incr  random-twice  \
# 0                       srittau__FakeSMTPd  0.870690      0.922414
# 1        scalableminds__webknossos-connect  0.723147      0.736762
# 2                  flopp__unicode-explorer  0.777778      0.863248
# 3                    eirannejad__calcatime  0.906250      0.906250
# 4                      jelford__webwatcher  0.765957      0.744681
# 5              road-master__video-archiver  0.861789      0.861789
# 6                    flopp__GpxTrackPoster  0.686347      0.701107
# 7                   boompig__book-classics  0.929412      0.929412
# 8                dropbox__sqlalchemy-stubs  0.690476      0.690476
# 9            reddit__baseplate.py-upgrader  0.829268      0.829268
# 10        typeddjango__pytest-mypy-plugins  0.721739      0.782609
# 11                linw1995__data_extractor  0.653846      0.684615
# 12                  albertyw__albertyw.com  0.671429      0.657143
# 13    marcosschroh__dataclasses-avroschema  0.557692      0.542308
# 14               antonagestam__collectfast  0.732759      0.758621
# 15                  ammarnajjar__pautomate  0.907407      0.925926
# 16                 brettkromkamp__topic-db  0.726190      0.693452
# 17                 basilisp-lang__basilisp  0.608710      0.492796
# 18             paulcwatts__drf-json-schema  0.624506      0.660079
# 19      ShadowTemplate__beautiful-python-3  0.915966      0.915966
# 20                    AxelVoitier__lookups  0.415525      0.479452
# 21    Gerschtli__teamspeak-update-notifier  0.761905      0.771429
# 22                        joshtemple__lkml  0.751220      0.834146
# 23                kitsuyui__bamboo-crawler  0.656805      0.680473
# 24          amplify-education__python-hcl2  0.739726      0.780822
# 25                         nubark__instark  0.887728      0.890339
# 26                    albertyw__git-browse  0.755556      0.722222
# 27                   kornicameister__axion  0.488473      0.465418
# 28                        payscale__fables  0.790323      0.766129
# 29                      nabla-c0d3__sslyze  0.777191      0.761352
# 30               rakitaj__daily-programmer  0.738889      0.750000
# 31          silasary__discord_connotations  0.666667      0.666667
# 32                          JakobGM__quelf  0.456522      0.456522
# 33                        ocf__slackbridge  0.741935      0.750000
# 34                      sonic182__aiosonic  0.803109      0.823834
# 35  lucaswerkmeister__tool-quickcategories  0.750455      0.772313
# 36                         ohjames__babies  0.850746      0.820896
# 37                   ClearcodeHQ__mirakuru  0.773196      0.804124
# 38                    futursolo__magichttp  0.581081      0.621622
# 39              ActivityWatch__aw-research  0.829060      0.837607
# 40                    lebrice__blurred-GAN  0.738095      0.690476
# 41                webrecorder__browsertrix  0.730469      0.714844
# 42                        seattleflu__id3c  0.709324      0.698355
# 43                    TomerFi__aioswitcher  0.768421      0.842105
# 44                    jfly__jfly.github.io  0.787879      0.818182
# 45                             jreese__aql  0.645320      0.704433
# 46           yeraydiazdiaz__wait_for_it.py  1.000000      1.000000
# 47                          cliffxuan__mew  0.704225      0.591549
# 48           everyclass__everyclass-server  0.777778      0.819820
# 49                       knowark__estimark  0.867220      0.896266
#
#     double-traversal  label_size  label_rate  labels
# 0           0.931034    1.232759    0.348348     116
# 1           0.760968    1.242057    0.830402     661
# 2           0.863248    1.145299    0.576355     117
# 3           0.906250    1.937500    0.800000      32
# 4           0.744681    1.319149    0.218605      47
# 5           0.869919    1.162602    0.416949     123
# 6           0.682657    1.247232    0.654589     271
# 7           0.929412    1.270588    0.586207      85
# 8           0.690476    1.261905    0.608696      42
# 9           0.847561    1.250000    0.438503     164
# 10          0.782609    1.695652    0.732484     115
# 11          0.669231    1.423077    0.248092     130
# 12          0.657143    1.600000    0.374332      70
# 13          0.534615    1.353846    0.293123     260
# 14          0.758621    1.258621    0.515556     116
# 15          0.925926    1.388889    0.504673      54
# 16          0.723214    1.145833    0.598930     336
# 17          0.617551    1.242633    0.525826    3054
# 18          0.656126    1.403162    0.533755     253
# 19          0.915966    1.142857    0.328729     119
# 20          0.447489    1.593607    0.337442     219
# 21          0.857143    1.161905    0.549738     105
# 22          0.814634    1.434146    0.395753     205
# 23          0.680473    1.751479    0.645038     169
# 24          0.821918    1.027397    0.730000      73
# 25          0.877285    1.172324    0.364762     383
# 26          0.777778    1.077778    0.462725     180
# 27          0.481268    1.644092    0.625789     694
# 28          0.798387    1.677419    0.366864     124
# 29          0.769799    1.269271    0.566049     947
# 30          0.766667    1.527778    0.500928     540
# 31          0.666667    1.400000    0.288462      15
# 32          0.467391    1.184783    0.528736      92
# 33          0.798387    1.370968    0.576744     124
# 34          0.730570    1.134715    0.285503     193
# 35          0.790528    1.510018    0.605292     549
# 36          0.820896    1.358209    0.325243      67
# 37          0.793814    1.855670    0.383399      97
# 38          0.675676    1.148649    0.354067     222
# 39          0.854701    1.675214    0.366771     117
# 40          0.678571    1.071429    0.188764      84
# 41          0.703125    1.175781    0.307323     256
# 42          0.716636    1.208410    0.449466     547
# 43          0.878947    1.142105    0.336283     190
# 44          0.818182    1.151515    0.237410      33
# 45          0.704433    1.438424    0.447137     203
# 46          1.000000    1.333333    0.375000       6
# 47          0.591549    1.028169    0.365979      71
# 48          0.783784    1.201201    0.372900     333
# 49          0.863071    1.327801    0.335655     241

# %%
df_sorted.to_csv(proj_root() / "data" / "accs_by_project.csv")

# %%
ex_proj = test_projects[29]
print("Project location:", ex_proj.root_dir)

evalr = evals["double-traversal"]
pid = evalr.project_roots.index(ex_proj.root_dir)
ex_analysis = evalr.error_analysis(pid, acc_metric)
ex_errors = ex_analysis.errors[ex_proj.root_dir.name]
ex_rollout = evalr.predictions[pid]

print("Number of errors:", len(ex_errors))
# Out:
# Project location: /mnt/data0/jiayi/SPOT/datasets/ManyTypes4Py/repos/test/nabla-c0d3__sslyze
# Number of errors: 218

# %%
from spot.utils import *

DefaultTokenizer.encode("<mask><mask>1", add_special_tokens=False)
# Out:
# [4, 4, 21]

# %%
# under predicted types sorted by frequency
under_pred_types = Counter()
over_predicted_types = Counter()
for pred in ex_errors:
    under_pred_types[acc_metric.process_type(pred.expected)] += 1
    over_predicted_types[acc_metric.process_type(pred.predicted)] += 1

print("Under-predicted types:")
display(under_pred_types.most_common(10))
print("Over-predicted types:")
display(over_predicted_types.most_common(10))
# Out:
# Under-predicted types:
# [(ty'ScanCommandExtraArgument', 15),
#  (ty'str', 13),
#  (ty'int', 12),
#  (ty'_MozillaTlsConfigurationAsJson', 6),
#  (ty'CipherSuitesScanAttemptAsJson', 6),
#  (ty'CipherSuitesScanAttempt', 6),
#  (ty'_Base64EncodedBytes', 5),
#  (ty'AllScanCommandsAttempts', 4),
#  (ty'ScanCommandResult', 4),
#  (ty'ClassVar[str]', 4)]
# Over-predicted types:
# [(ty'str', 31),
#  (ty'Any', 21),
#  (ty'ScanCommandsExtraArguments', 19),
#  (ty'...', 6),
#  (ty'ServerScanResult', 5),
#  (ty'ScanCommandResult', 5),
#  (ty'float', 4),
#  (ty'Dict[str, str]', 4),
#  (ty'int', 4),
#  (ty'bool', 4)]

# %%
from spot.static_analysis import ProjectPath

error_id = 100
pred = ex_errors[error_id]
print("----------------------")
print("Elem Path:", pred.path)
print("Type Index:", pred.index)
evalr.inspect_elem(pid, pred.path)
# evalr.inspect_elem(pid, ProjectPath.from_str("tests.factories/AllScanCommandsAttemptsFactory.create"))
# Out:
# ----------------------
# Elem Path: sslyze.plugins.openssl_cipher_suites.json_output/CipherSuitesScanResultAsJson.from_orm
# Type Index: 2
# Expected:  MethodSig((cls, scan_result: CipherSuitesScanResult) -> "CipherSuitesScanResultAsJson")
# Predicted: MethodSig((cls: Any, scan_result: CipherSuitesScanResult) -> Any)
# Code:
# import pydantic
# from base64 import b64encode
# from typing import List, Optional
# from nassl.ephemeral_key_info import EphemeralKeyInfo, EcDhEphemeralKeyInfo, NistEcDhKeyExchangeInfo, DhEphemeralKeyInfo
# from sslyze.json.scan_attempt_json import ScanCommandAttemptAsJson
# from sslyze.plugins.openssl_cipher_suites.implementation import (
#     CipherSuitesScanResult,
#     CipherSuiteAcceptedByServer,
# )
# class _BaseModelWithOrmMode(pydantic.BaseModel):
#    ...
# class _CipherSuiteAsJson(_BaseModelWithOrmMode):
#    ...
# _Base64EncodedBytes = str
# class _EphemeralKeyInfoAsJson(_BaseModelWithOrmMode):
#    ...
# class _CipherSuiteAcceptedByServerAsJson(_BaseModelWithOrmMode):
#    ...
# class _CipherSuiteRejectedByServerAsJson(_BaseModelWithOrmMode):
#    ...
# class CipherSuitesScanResultAsJson(_BaseModelWithOrmMode):
#    ...
# class CipherSuitesScanAttemptAsJson(ScanCommandAttemptAsJson):
#    ...
# # sslyze.json.json_output
# class AllScanCommandsAttemptsAsJson(_BaseModelWithOrmModeAndForbid):
#     @classmethod
#     def from_orm(cls: Any, all_scan_commands_attempts: AllScanCommandsAttempts) -> Any:...
#
#
# # sslyze.json.json_output
# class _ServerTlsProbingResultAsJson(_BaseModelWithOrmModeAndForbid):
#     @classmethod
#     def from_orm(cls: Any, tls_probing_result: ServerTlsProbingResult) -> Any:...
#
#
# # sslyze.plugins.openssl_cipher_suites.implementation
# @dataclass(frozen=True)
# class CipherSuitesScanResult(ScanCommandResult):
#     tls_version_used: TlsVersionEnum
#     accepted_cipher_suites: List[CipherSuite]
#     rejected_cipher_suites: List[CipherSuite]
#     @property
#     def is_tls_version_supported(self) -> bool:...
#
#
# # sslyze.plugins.openssl_cipher_suites.json_output
# class CipherSuitesScanResultAsJson(_BaseModelWithOrmMode):
#     tls_version_used: pydantic.TLSVersion
#     is_tls_version_supported: bool
#     accepted_cipher_suites: List[CipherSuite]
#     rejected_cipher_suites: List[pydantic.BaseModel]
#
# # sslyze.plugins.certificate_info.json_output
# class _ObjectIdentifierAsJson(_BaseModelWithOrmMode):
#     name: str
#
# # sslyze.plugins.certificate_info.trust_stores.trust_store
# @dataclass(frozen=True)
# class TrustStore:
#     name: str
#
# # sslyze.plugins.elliptic_curves_plugin
# class _EllipticCurveAsJson(pydantic.BaseModel):
#     name: str
#
# # sslyze.plugins.openssl_cipher_suites.json_output
# class _CipherSuiteAsJson(_BaseModelWithOrmMode):
#     name: str
#
# # sslyze.plugins.elliptic_curves_plugin
# @dataclass(frozen=True)
# class EllipticCurve:
#     name: str
#
# # sslyze.plugins.openssl_cipher_suites.cipher_suites
# @dataclass(frozen=True)
# class CipherSuite:
#     name: str
#
# # sslyze.plugins.certificate_info.json_output
# class _TrustStoreAsJson(_BaseModelWithOrmMode):
#     name: str
#
# # sslyze.plugins.certificate_info.json_output
# class _HashAlgorithmAsJson(_BaseModelWithOrmMode):
#     name: str
#
# # Used above
# # sslyze.plugins.openssl_cipher_suites.json_output
# class CipherSuitesScanResultAsJson(_BaseModelWithOrmMode):
#     @classmethod
#     def from_orm(cls: <extra_id_0>, scan_result: <extra_id_1>) -> <extra_id_2>:
#         return cls(
#             tls_version_used=scan_result.tls_version_used.name,
#             is_tls_version_supported=scan_result.is_tls_version_supported,
#             accepted_cipher_suites=scan_result.accepted_cipher_suites,
#             rejected_cipher_suites=scan_result.rejected_cipher_suites,
#         )
#
#
# # Users below
# # sslyze.json.json_output
# class ServerScanResultAsJson(_BaseModelWithOrmModeAndForbid):
#     @classmethod
#     def from_orm(cls: Any, server_scan_result: ServerScanResult) -> Any:
#         connectivity_error_trace_as_str = None
#         if server_scan_result.connectivity_error_trace:
#             connectivity_error_trace_as_str = ""
#             for line in server_scan_result.connectivity_error_trace.format(chain=False):
#                 connectivity_error_trace_as_str += line
#
#         connectivity_result_as_json:...
#         if server_scan_result.connectivity_result:
#             connectivity_result_as_json = _ServerTlsProbingResultAsJson.from_orm(server_scan_result.connectivity_result)
#         else:
#             connectivity_result_as_json = None
#
#         scan_result_as_json:...
#         if server_scan_result.scan_result:
#             scan_result_as_json = AllScanCommandsAttemptsAsJson.from_orm(server_scan_result.scan_result)
#         else:
#             scan_result_as_json = None
#
#         return cls(
#             uuid=server_scan_result.uuid,
#             server_location=_ServerNetworkLocationAsJson.from_orm(server_scan_result.server_location),
#             network_configuration=_ServerNetworkConfigurationAsJson.from_orm(server_scan_result.network_configuration),
#             connectivity_status=server_scan_result.connectivity_status,
#             connectivity_error_trace=connectivity_error_trace_as_str,
#             connectivity_result=connectivity_result_as_json,
#             scan_status=server_scan_result.scan_status,
#             scan_result=scan_result_as_json,
#         )
