# %%
# %load_ext autoreload
# %autoreload 2

# first, load the trained model
import os
import torch
from typing import *

from spot.model import ModelWrapper
from spot.utils import get_model_dir, proj_root

os.chdir(proj_root())

# gpu_id = 1
# modeldir = get_model_dir()

model_name="model-v5--TrainingConfig(drop_env_types=False)"
dataset_name = "ManyTypes4Py"

# %%
from spot.utils import *
from spot.function_dataset import data_project_from_dir

# load test projects
repos_dir = get_dataset_dir(dataset_name) / "repos" / "test"
test_repo_paths = [f for f in repos_dir.iterdir() if f.is_dir()]
test_projects = pmap(
    data_project_from_dir,
    test_repo_paths,
    desc="Loading test projects",
)
assert len(test_projects) > 0
# Out:
# Loading test projects: 100%|██████████| 50/50 [00:20<00:00,  2.43it/s]

# %%
from spot.function_decoding import DecodingOrders, EvalResult

results_dir = get_eval_dir(dataset_name, model_name)

decode_orders = {
    "no-neighbors": DecodingOrders.IndependentOrder(),
    "non-incr": DecodingOrders.IndependentOrder(),
    "random": DecodingOrders.RandomOrder(),
    "double-traversal": DecodingOrders.DoubleTraversal(),
    "callee2caller": DecodingOrders.Callee2Caller(),
    "caller2callee": DecodingOrders.Caller2Callee(),
}

evals = dict[str, EvalResult]()

for oname in tqdm(decode_orders, desc="Loading evaluation results"):
    evals[oname] = pickle_load(results_dir / f"{oname}-EvalResult.pkl")
# Out:
# Loading evaluation results: 100%|██████████| 6/6 [00:13<00:00,  2.24s/it]

# %%
import pandas as pd
from spot.type_env import AccuracyMetric

projects = [p.root_dir.name for p in test_projects]
common_type_names = ModelWrapper.load_common_type_names(get_model_dir() / model_name)

strategies_to_show = ["no-neighbors", "non-incr", "double-traversal"]
acc_metric = AccuracyMetric(common_type_names)
strategy2accs = {
    s: [
        evals[s].error_analysis(pname, acc_metric).accuracies[acc_metric.name]
        for pname in projects
    ]
    for s in strategies_to_show
}

n_annots = [
    sum(e.get_signature().n_annots() for e in p.all_elems()) for p in test_projects
]
# n_labels = [
#     sum(e.get_signature().n_annotated() for e in p.all_elems()) for p in test_projects
# ]
n_labels = [x.n_total for x in strategy2accs[strategies_to_show[0]]]

label_rates = [a / b for a, b in zip(n_labels, n_annots)]

df = pd.DataFrame(
    {
        "project": projects,
        **{n: [x.acc for x in xs] for n, xs in strategy2accs.items()},
        "label_rate": label_rates,
        "labels": n_labels,
    }
)
df.sort_values(by=["labels"], ascending=False)
# Out:
#                                    project  no-neighbors  non-incr  \
# 17                 basilisp-lang__basilisp      0.614854  0.648702
# 29                      nabla-c0d3__sslyze      0.752391  0.788523
# 27                   kornicameister__axion      0.517385  0.536857
# 1        scalableminds__webknossos-connect      0.694888  0.769968
# 30               rakitaj__daily-programmer      0.838889  0.866667
# 42                        seattleflu__id3c      0.757874  0.860236
# 13    marcosschroh__dataclasses-avroschema      0.544419  0.528474
# 25                         nubark__instark      0.829457  0.868217
# 48           everyclass__everyclass-server      0.735736  0.804805
# 35  lucaswerkmeister__tool-quickcategories      0.793548  0.806452
# 6                    flopp__GpxTrackPoster      0.557196  0.664207
# 18             paulcwatts__drf-json-schema      0.723485  0.704545
# 41                webrecorder__browsertrix      0.632812  0.714844
# 49                       knowark__estimark      0.863071  0.854772
# 38                    futursolo__magichttp      0.527027  0.635135
# 20                    AxelVoitier__lookups      0.634703  0.666667
# 22                        joshtemple__lkml      0.760976  0.804878
# 45                             jreese__aql      0.764103  0.774359
# 34                      sonic182__aiosonic      0.839378  0.844560
# 43                    TomerFi__aioswitcher      0.757895  0.826316
# 26                    albertyw__git-browse      0.633333  0.755556
# 23                kitsuyui__bamboo-crawler      0.715976  0.739645
# 9            reddit__baseplate.py-upgrader      0.825806  0.819355
# 11                linw1995__data_extractor      0.653846  0.715385
# 33                        ocf__slackbridge      0.693548  0.709677
# 28                        payscale__fables      0.862903  0.919355
# 5              road-master__video-archiver      0.861789  0.910569
# 19      ShadowTemplate__beautiful-python-3      0.899160  0.966387
# 39              ActivityWatch__aw-research      0.897436  0.897436
# 2                  flopp__unicode-explorer      0.820513  0.871795
# 14               antonagestam__collectfast      0.750000  0.758621
# 0                       srittau__FakeSMTPd      0.844828  0.896552
# 10        typeddjango__pytest-mypy-plugins      0.808696  0.843478
# 21    Gerschtli__teamspeak-update-notifier      0.638095  0.704762
# 16                 brettkromkamp__topic-db      0.866667  0.895238
# 37                   ClearcodeHQ__mirakuru      0.721649  0.742268
# 32                          JakobGM__quelf      0.543478  0.565217
# 7                   boompig__book-classics      0.917647  0.952941
# 40                    lebrice__blurred-GAN      0.714286  0.636364
# 24          amplify-education__python-hcl2      0.890411  0.890411
# 47                          cliffxuan__mew      0.763889  0.833333
# 12                  albertyw__albertyw.com      0.571429  0.671429
# 36                         ohjames__babies      0.865672  0.910448
# 15                  ammarnajjar__pautomate      0.888889  0.907407
# 4                      jelford__webwatcher      0.787234  0.808511
# 8                dropbox__sqlalchemy-stubs      0.690476  0.761905
# 44                    jfly__jfly.github.io      0.696970  0.818182
# 3                    eirannejad__calcatime      0.812500  0.843750
# 31          silasary__discord_connotations      0.615385  0.692308
# 46           yeraydiazdiaz__wait_for_it.py      1.000000  1.000000
#
#     double-traversal  label_rate  labels
# 17          0.646073    0.526926    3043
# 29          0.797024    0.568924     941
# 27          0.495132    0.630149     719
# 1           0.793930    0.830239     626
# 30          0.883333    0.500928     540
# 42          0.879921    0.442509     508
# 13          0.510251    0.427875     439
# 25          0.873385    0.346774     387
# 48          0.762763    0.372900     333
# 35          0.796774    0.658174     310
# 6           0.719557    0.654589     271
# 18          0.761364    0.528000     264
# 41          0.707031    0.307323     256
# 49          0.854772    0.335655     241
# 38          0.716216    0.354067     222
# 20          0.621005    0.334351     219
# 22          0.819512    0.395753     205
# 45          0.769231    0.437220     195
# 34          0.797927    0.291982     193
# 43          0.900000    0.336283     190
# 26          0.766667    0.462725     180
# 23          0.733728    0.645038     169
# 9           0.851613    0.430556     155
# 11          0.707692    0.230906     130
# 33          0.790323    0.576744     124
# 28          0.927419    0.366864     124
# 5           0.926829    0.416949     123
# 19          0.949580    0.328729     119
# 39          0.914530    0.366771     117
# 2           0.923077    0.576355     117
# 14          0.827586    0.515556     116
# 0           0.905172    0.348348     116
# 10          0.869565    0.732484     115
# 21          0.723810    0.549738     105
# 16          0.923810    0.363322     105
# 37          0.773196    0.383399      97
# 32          0.554348    0.528736      92
# 7           0.964706    0.586207      85
# 40          0.701299    0.184211      77
# 24          0.958904    0.730000      73
# 47          0.777778    0.369231      72
# 12          0.642857    0.374332      70
# 36          0.895522    0.325243      67
# 15          0.962963    0.504673      54
# 4           0.787234    0.218605      47
# 8           0.738095    0.608696      42
# 44          0.969697    0.237410      33
# 3           0.875000    0.800000      32
# 31          0.692308    0.270833      13
# 46          1.000000    0.375000       6

# %%
df.to_csv(proj_root() / "data" / "accs_by_project.csv")

# %%
ex_proj = test_projects[27]
print("Project location:", ex_proj.root_dir)

pid = evals["double-traversal"].project_roots.index(ex_proj.root_dir)
ex_analysis = evals["double-traversal"].error_analysis(pid, acc_metric)
ex_errors = ex_analysis.errors[ex_proj.root_dir.name]
ex_rollout = evals["double-traversal"].predictions[pid]

print("Number of errors:", len(ex_errors))
# Out:
# Project location: /mnt/data0/jiayi/SPOT/datasets/ManyTypes4Py/repos/test/kornicameister__axion
# Number of errors: 363

# %%
from spot.type_env import PythonType, normalize_type, remove_top_optional

remove_top_optional(normalize_type(PythonType.from_str("t.Optional[t.Dict[str, t.Any]]")))
# Out:
# ty't.Dict[t.Any]'

# %%
# under predicted types sorted by frequency
under_pred_types = Counter()
over_predicted_types = Counter()
for pred in ex_errors:
    under_pred_types[pred.expected] += 1
    over_predicted_types[pred.predicted] += 1

print("Under-predicted types:")
display(under_pred_types.most_common(10))
print("Over-predicted types:")
display(over_predicted_types.most_common(10))
# Out:
# Under-predicted types:
# [(ty't.Dict[str, t.Any]', 45),
#  (ty'str', 30),
#  (ty'logging.LogCaptureFixture', 21),
#  (ty't.Type[t.Any]', 18),
#  (ty't.Optional[t.Dict[str, t.Any]]', 14),
#  (ty't.Dict[str, t.Dict[str, t.Any]]', 11),
#  (ty't.Tuple[t.Set[exceptions.Error], model.ParamMapping]', 11),
#  (ty'oas.OASOperation', 10),
#  (ty'ptm.MockFixture', 10),
#  (ty'pipeline.Response', 8)]
# Over-predicted types:
# [(ty't.Any', 66),
#  (ty't.Mapping[str, t.Any]', 34),
#  (ty'logging.Logger', 20),
#  (ty't.Mapping[str, t.Mapping[str, t.Any]]', 17),
#  (ty'int', 15),
#  (ty't.Tuple[t.Set[str], t.Dict[str, t.Any]]', 10),
#  (ty't.Dict[str, t.Any]', 9),
#  (ty'ptm.Mock', 9),
#  (ty'model.Parameter', 8),
#  (ty't.Mapping[str, str]', 7)]

# %%
from spot.static_analysis import ProjectPath

error_id = 100
pred = ex_errors[error_id]
print("----------------------")
print("Elem Path:", pred.path)
print("Type Index:", pred.index)
evals["double-traversal"].inspect_elem(pid, pred.path)
# Out:
# ----------------------
# Elem Path: tests.schemas.conftest/UnionSchema.lake_trip
# Type Index: 0
# Expected:  AttrSig(cst'typing.Union[Bus, Car]')
# Predicted: AttrSig(cst'...')
# Code:
# import datetime
# import json
# import os
# import enum
# import typing
# import uuid
# import pytest
# from pydantic import Field
# from dataclasses_avroschema.avrodantic import AvroBaseModel
#
#
# # Used:
#
# # Target:
# # tests.schemas.conftest
# class UnionSchema(AvroBaseModel):
#     lake_trip: <extra_id_0> = Field(default_factory=lambda: Bus(engine_name="honda"))
#
# # Users:
# # tests.schemas.test_pydantic
# def test_pydantic_record_schema_with_unions_type(union_type_schema: typing.Mapping[str, UnionSchema]) -> None:
#     class Bus(AvroBaseModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.bus_type"
#
#     class Car(AvroBaseModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.car_type"
#
#     class TripDistance(enum.Enum):
#         CLOSE = "Close"
#         FAR = "Far"
#
#         class Meta:
#             doc = "Distance of the trip"
#
#     class UnionSchema(AvroBaseModel):
#         first_union:...
#         logical_union:...
#         lake_trip:...
#         river_trip:... = None
#         mountain_trip:... = Field(default_factory=lambda: {"engine_name": "honda"})
#         trip_distance:... = None
#
#     assert UnionSchema.avro_schema() == json.dumps(union_type_schema)
#
# # tests.schemas.test_faust
# @pytest.mark.skip(reason="skiping conflict with new faust-streaming version")
# def test_faust_record_schema_with_unions_type(union_type_schema: typing.Mapping[str, UnionSchema]) -> None:
#     class Bus(faust.Record, AvroModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.bus_type"
#
#     class Car(faust.Record, AvroModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.car_type"
#
#     class TripDistance(enum.Enum):
#         CLOSE = "Close"
#         FAR = "Far"
#
#         class Meta:
#             doc = "Distance of the trip"
#
#     class UnionSchema(faust.Record, AvroModel):
#         first_union:...
#         logical_union:...
#         lake_trip:...
#         river_trip:... = None
#         mountain_trip:... = dataclasses.field(default_factory=lambda: {"engine_name": "honda"})
#         trip_distance:... = None
#
#     assert UnionSchema.avro_schema() == json.dumps(union_type_schema)
#
# # tests.schemas.test_schema_with_complex_types
# def test_schema_with_unions_type(union_type_schema: typing.Mapping[str, UnionSchema]) -> None:
#     class Bus(AvroModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.bus_type"
#
#     class Car(AvroModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.car_type"
#
#     class TripDistance(enum.Enum):
#         CLOSE = "Close"
#         FAR = "Far"
#
#         class Meta:
#             doc = "Distance of the trip"
#
#     class UnionSchema(AvroModel):
#         first_union:...
#         logical_union:...
#         lake_trip:...
#         river_trip:... = None
#         mountain_trip:... = dataclasses.field(default_factory=lambda: {"engine_name": "honda"})
#         trip_distance:... = None
#
#     assert parse_schema(UnionSchema.avro_schema_to_python())
#     assert UnionSchema.avro_schema() == json.dumps(union_type_schema)
#
# # tests.schemas.conftest
# @pytest.fixture
# def AvroBaseModel_model() -> typing.Type[UnionSchema]:
#     class Bus(AvroBaseModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.bus_type"
#
#     class Car(AvroBaseModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.car_type"
#
#     class TripDistance(str, enum.Enum):
#         CLOSE = "Close"
#         FAR = "Far"
#
#         class Meta:
#             doc = "Distance of the trip"
#
#     class UnionSchema(AvroBaseModel):
#         first_union:...
#         logical_union:...
#         lake_trip:... = Field(default_factory=lambda: Bus(engine_name="honda"))
#         river_trip:... = None
#         mountain_trip:... = Field(default_factory=lambda: {"engine_name": "honda"})
#         trip_distance:... = None
#
#     return UnionSchema
#
# # tests.fake.test_fake
# def test_fake_union() -> None:
#     class Bus(AvroModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.bus_type"
#
#     class Car(AvroModel):
#         engine_name:...
#
#         class Meta:
#             namespace = "types.car_type"
#
#     class UnionSchema(AvroModel):
#         first_union:...
#         logical_union:...
#         lake_trip:...
#         river_trip:... = None
#         mountain_trip:... = dataclasses.field(default_factory=lambda: {"engine_name": "honda"})
#
#     assert isinstance(UnionSchema.fake(), UnionSchema)
